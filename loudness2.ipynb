# %%
import numpy as np
import librosa
import matplotlib.pyplot as plt

# %%
Fs = 22050
x, Fs = librosa.load('data/lofi-type-beat.mp3', sr=Fs, mono=True)

# %%
rms = librosa.feature.rms(y=x)[0]
loudness = (rms - np.min(rms)) / (np.max(rms) - np.min(rms))

# %%
times = librosa.times_like(loudness)
times
# Out:
# array([0.00000000e+00, 2.32199546e-02, 4.64399093e-02, ...,
#        1.50604626e+02, 1.50627846e+02, 1.50651066e+02])

# %%
plt.plot(times, loudness)
