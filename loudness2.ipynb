# %%
import numpy as np
import librosa

# %%
Fs = 22050
x, Fs = librosa.load('data/beethoven.mp3', sr=Fs, mono=True)

# %%
rms = librosa.feature.rms(y=x)[0]
loudness = (rms - np.min(rms)) / (np.max(rms) - np.min(rms))

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(loudness)
